# %%
# Import data
import pandas as pd
stock_data = pd.read_csv('./NFLX.csv',index_col='Date')
stock_data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-27  345.950012  351.899994  341.019989  342.880005  342.880005
# 2020-01-28  345.880005  352.399994  342.779999  348.519989  348.519989
# 2020-01-29  349.000000  349.399994  338.549988  343.160004  343.160004
# 2020-01-30  341.100006  348.200012  339.250000  347.739990  347.739990
# 2020-01-31  347.390015  347.390015  340.980011  345.089996  345.089996
#
#              Volume
# Date
# 2020-01-27  7709500
# 2020-01-28  6821600
# 2020-01-29  7643500
# 2020-01-30  5328100
# 2020-01-31  5230000

# %%
# plot graph
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import datetime as dt

plt.figure(figsize=(15,10))

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=60))
x_dates = [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in stock_data.index.values]

plt.plot(x_dates, stock_data['High'], label='High')
plt.plot(x_dates, stock_data['Low'], label='Low')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()


plt.plot(x_dates, stock_data['Open'], label='Open')
plt.plot(x_dates, stock_data['Close'], label='Close')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()
